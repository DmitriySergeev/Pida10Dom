# %% [markdown]
# **Задание 1**. Даны 2 строки: *long_phrase* и *short_phrase*.
# Напишите код, который проверяет действительно ли длинная фраза *long_phrase* длиннее короткой *short_phrase*. И выводит *True* или *False* в зависимости от результата сравнения.

# %%
long_phrase = 'Насколько проще было бы писать программы, если бы не заказчики'
short_phrase = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'

# %%
long_phrase == short_phrase
# Out:
# False

# %% [markdown]
# **Задание 2**. Дано значение объема файла в байтах (*в мегабайте 2^20 байт*). Напишите перевод этого значения в мегабайты в формате: "*Объем файла равен 213.68Mb*".

# %%
c=int(input("Введите количество байт"))
x = c ** (1./(2^20))
x1 = round (x, 2)
print ("Объем файла равен", x1, "Mb")
# Out:
# Введите количество байт4354312322
# Объем файла равен 2.74 Mb

# %% [markdown]
# **Задание 3**. Разработать приложение для определения знака зодиака по дате рождения. Пример:
#
# Введите месяц: март
#
# Введите число: 6
#
# Вывод:
# Рыбы

# %%
m = (input ("Введите месяц"))
d = int(input("Введите дату"))
m1 = "январь"
m2 = "февраль"
m3 = "март"
m4 = "апрель"
m5 = "май"
m6 = "июнь"
m7 = "июль"
m8 = "авгус"
m9 = "сентябрь"
m10 = "октябрь"
m11 = "ноябрь"
m12 = "декабрь"
if m == m1 and d <= 19:
    print ("Козерог")
elif m == m1 and d > 19:
        print ("Водолей")
elif m == m2 and d <= 18:
    print ("Водолей")
elif m == m2 and d > 18:
        print ("Рыбы")
elif m == m3 and d <= 20:
    print ("Рыбы")
elif m == m3 and d > 20:
        print ("Овен")
elif m == m4 and d <= 20:
    print ("Овен")
elif m == m4 and d > 20:
        print ("Телец")
elif m == m5 and d <= 20:
    print ("Телец")
elif m == m5 and d > 20:
        print ("Близнецы")
elif m == m6 and d <= 20:
    print ("Близнецы")
elif m == m6 and d > 20:
        print ("Рак")
elif m == m7 and d <= 22:
    print ("Рак")
elif m == m7 and d > 22:
        print ("Лев")
elif m == m8 and d <= 22:
    print ("Лев")
elif m == m8 and d > 22:
        print ("Дева")
elif m == m9 and d <= 23:
    print ("Дева")
elif m == m9 and d > 23:
        print ("Весы")
elif m == m10 and d <= 23:
    print ("Весы")
elif m == m10 and d > 23:
        print ("Скорпион")
elif m == m11 and d <= 21:
    print ("Скорпион")
elif m == m11 and d > 21:
        print ("Стрелец")
elif m == m12 and d <= 21:
    print ("Стрелец")
elif m == m12 and d > 21:
        print ("Козерог")
# Out:
# Введите месяциюнь
# Введите дату17
# Близнецы

# %% [markdown]
# **Задание 4**. Нужно разработать приложение для финансового планирования.
# Приложение учитывает сколько уходит на ипотеку, "на жизнь" и сколько нужно отложить на пенсию.
# Пользователь вводит:
# - заработанную плату в месяц.
# - сколько процентов от ЗП уходит на ипотеку.
# - сколько процентов от ЗП уходит "на жизнь".
# - сколько раз приходит премия в год.
#
# Остальная часть заработанной платы откладывается на пенсию.
#
# Также пользователю приходит премия в размере зарплаты, от которой половина уходит на отпуск, а вторая половина откладывается.
#
# Программа должна учитывать сколько премий было в год.
#
# Нужно вывести сколько денег тратит пользователь на ипотеку и сколько он накопит за год.
#
# Пример:
#
# Введите заработанную плату в месяц: 100000
#
# Введите сколько процентов уходит на ипотеку: 30
#
# Введите сколько процентов уходит на жизнь: 50
#
# Введите количество премий за год: 2
#
# Вывод:
# На ипотеку было потрачено: 360000 рублей
# Было накоплено: 340000 рублей

# %%
zp = int(input("Введите заработную плату в месяц"))
pr_ipoteka = int(input("Сколько процентов от зарплаты уходит на ипотеку"))
pr_zhizn = int(input("Сколько процентов от зарплаты ухдит на жизнь"))
kol_premiy = int(input("Введите количество премий, полученных за год"))
pensiya = (((100 - pr_ipoteka - pr_zhizn) / 100) * (12 * zp))+(0.5 * zp * kol_premiy)
ipoteka = (pr_ipoteka/100)*(12*zp)
print ("На ипотеку потрачено", ipoteka, "рублей.  ", "Было отложено", pensiya, "рублей.")
# Out:
# Введите заработную плату в месяц100000
# Сколько процентов от зарплаты уходит на ипотеку30
# Сколько процентов от зарплаты ухдит на жизнь50
# Введите количество премий, полученных за год2
# На ипотеку потрачено 360000.0 рублей.   Было отложено 340000.0 рублей.
